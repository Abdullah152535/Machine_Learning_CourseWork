# %% [markdown]
# # Multiple Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Housing.csv')

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ## Univariate Analysis

# %%
sns.countplot(data['furnishingstatus'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='furnishingstatus'>

# %%
plt.hist(data['area'],bins=10)
# Out:
# (array([ 73., 198., 117.,  88.,  39.,  15.,   8.,   5.,   0.,   2.]),
#  array([ 1650.,  3105.,  4560.,  6015.,  7470.,  8925., 10380., 11835.,
#         13290., 14745., 16200.]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(data['price'])

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical-Numerical

# %%
sns.scatterplot(x=data['area'],y=data['price'],hue=data['furnishingstatus'],size=data['stories'])
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=data['stories'],y=data['price'],hue=data['furnishingstatus'])
# Out:
# <AxesSubplot:xlabel='stories', ylabel='price'>
